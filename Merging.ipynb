# %%
# Dependencies
import pandas as pd
import numpy as np
import os
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')
import datetime
from dateutil.relativedelta import relativedelta
from datetime import date

# %%
# Reading csv files

data1 = pd.read_csv('Resources/JC-201901-citibike-tripdata.csv')
data2 = pd.read_csv('Resources/JC-201902-citibike-tripdata.csv')
data3 = pd.read_csv('Resources/JC-201903-citibike-tripdata.csv')
data4 = pd.read_csv('Resources/JC-201904-citibike-tripdata.csv')
data5 = pd.read_csv('Resources/JC-201905-citibike-tripdata.csv')
data6 = pd.read_csv('Resources/JC-201906-citibike-tripdata.csv')
data7 = pd.read_csv('Resources/JC-201907-citibike-tripdata.csv')
data8 = pd.read_csv('Resources/JC-201908-citibike-tripdata.csv')
data9 = pd.read_csv('Resources/JC-201909-citibike-tripdata.csv')
data10 = pd.read_csv('Resources/JC-201910-citibike-tripdata.csv')
data11 = pd.read_csv('Resources/JC-201911-citibike-tripdata.csv')
data12 = pd.read_csv('Resources/JC-201912-citibike-tripdata.csv')

data01 = pd.read_csv('Resources/JC-202001-citibike-tripdata.csv')
data02 = pd.read_csv('Resources/JC-202002-citibike-tripdata.csv')
data03 = pd.read_csv('Resources/JC-202003-citibike-tripdata.csv')
data04 = pd.read_csv('Resources/JC-202004-citibike-tripdata.csv')
data05 = pd.read_csv('Resources/JC-202005-citibike-tripdata.csv')
data06 = pd.read_csv('Resources/JC-202006-citibike-tripdata.csv')
data07 = pd.read_csv('Resources/JC-202007-citibike-tripdata.csv')
data08 = pd.read_csv('Resources/JC-202008-citibike-tripdata.csv')
data09 = pd.read_csv('Resources/JC-202009-citibike-tripdata.csv')
data010 = pd.read_csv('Resources/JC-202010-citibike-tripdata.csv')
data011 = pd.read_csv('Resources/JC-202011-citibike-tripdata.csv')
data012 = pd.read_csv('Resources/JC-202012-citibike-tripdata.csv')
# data_1 = pd.read_csv('Resources/JC-202101-citibike-tripdata.csv')

# data_2 = pd.read_csv('Resources/JC-202102-citibike-tripdata.csv')
# data_3 = pd.read_csv('Resources/JC-202103-citibike-tripdata.csv')
# data_4 = pd.read_csv('Resources/JC-202104-citibike-tripdata.csv')
# data_5 = pd.read_csv('Resources/JC-202105-citibike-tripdata.csv')
# data_6 = pd.read_csv('Resources/JC-202106-citibike-tripdata.csv')
# data_7 = pd.read_csv('Resources/JC-202107-citibike-tripdata.csv')
# data_8 = pd.read_csv('Resources/JC-202108-citibike-tripdata.csv')
# data_9 = pd.read_csv('Resources/JC-202109-citibike-tripdata.csv')
# data_10 = pd.read_csv('Resources/JC-202110-citibike-tripdata.csv')
# data_11= pd.read_csv('Resources/JC-202111-citibike-tripdata.csv')
# data_12= pd.read_csv('Resources/JC-202112-citibike-tripdata.csv')

# %%
frames2019 = [data1,data2,data3,data4,data5,data6,data7,data8,data9,data10,data11,data12]
frames2020 = [data01,data02,data03,data04,data05,data06,data07,data08,data09,data010,data011,data012]
# frames2021 = [data_2,data_3,data_4,data_5,data_6,data_7,data_8,data_9,data_10,data_11,data_12]

result2019 = pd.concat(frames2019)
result2020 = pd.concat(frames2020)
# result2021 = pd.concat(frames2021)

# %%
result2020.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           226  2020-01-01 00:04:50.1920  2020-01-01 00:08:37.0370
# 1           377  2020-01-01 00:16:01.6700  2020-01-01 00:22:19.0800
# 2           288  2020-01-01 00:17:33.8770  2020-01-01 00:22:22.4420
# 3           435  2020-01-01 00:32:05.9020  2020-01-01 00:39:21.0660
# 4           231  2020-01-01 00:46:19.6780  2020-01-01 00:50:11.3440
#
#    start station id start station name  start station latitude  \
# 0              3186      Grove St PATH               40.719586
# 1              3186      Grove St PATH               40.719586
# 2              3186      Grove St PATH               40.719586
# 3              3195            Sip Ave               40.730897
# 4              3186      Grove St PATH               40.719586
#
#    start station longitude  end station id  end station name  \
# 0               -74.043117            3211        Newark Ave
# ...

# %%
result2019.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           201  2019-01-01 03:09:09.7110  2019-01-01 03:12:30.8790
# 1           505  2019-01-01 05:18:00.1060  2019-01-01 05:26:25.9050
# 2           756  2019-01-01 10:36:33.3400  2019-01-01 10:49:10.2600
# 3          1575  2019-01-01 12:43:38.6430  2019-01-01 13:09:54.5280
# 4          1566  2019-01-01 12:43:39.6010  2019-01-01 13:09:46.5100
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id    end station name  \
# 0               -74.033459            3214    Essex Light Rail
# ...

# %%
# result2021.head()

# %%
result2020["usertype"] = result2020["usertype"].str.replace('Customer','casual')
result2020["usertype"] = result2020["usertype"].str.replace('Subscriber','member')
result2019["usertype"] = result2019["usertype"].str.replace('Customer','casual')
result2019["usertype"] = result2019["usertype"].str.replace('Subscriber','member')

# %%
result2020.dropna()
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               226  2020-01-01 00:04:50.1920  2020-01-01 00:08:37.0370
# 1               377  2020-01-01 00:16:01.6700  2020-01-01 00:22:19.0800
# 2               288  2020-01-01 00:17:33.8770  2020-01-01 00:22:22.4420
# 3               435  2020-01-01 00:32:05.9020  2020-01-01 00:39:21.0660
# 4               231  2020-01-01 00:46:19.6780  2020-01-01 00:50:11.3440
# ...             ...                       ...                       ...
# 11689          1750  2020-12-31 23:07:44.0030  2020-12-31 23:36:54.4710
# 11690          1519  2020-12-31 23:18:00.2630  2020-12-31 23:43:19.8590
# 11691          1761  2020-12-31 23:31:09.4620  2021-01-01 00:00:31.3290
# 11692           637  2020-12-31 23:35:45.4640  2020-12-31 23:46:22.7300
# 11693          1607  2020-12-31 23:48:34.5750  2021-01-01 00:15:22.3090
#
#        start station id start station name  start station latitude  \
# ...

# %%
result2019.dropna()
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               201  2019-01-01 03:09:09.7110  2019-01-01 03:12:30.8790
# 1               505  2019-01-01 05:18:00.1060  2019-01-01 05:26:25.9050
# 2               756  2019-01-01 10:36:33.3400  2019-01-01 10:49:10.2600
# 3              1575  2019-01-01 12:43:38.6430  2019-01-01 13:09:54.5280
# 4              1566  2019-01-01 12:43:39.6010  2019-01-01 13:09:46.5100
# ...             ...                       ...                       ...
# 19723           283  2019-12-31 23:12:18.5480  2019-12-31 23:17:01.8740
# 19724           267  2019-12-31 23:19:03.5840  2019-12-31 23:23:30.6640
# 19725           379  2019-12-31 23:19:06.5830  2019-12-31 23:25:25.7970
# 19726           188  2019-12-31 23:24:00.2630  2019-12-31 23:27:09.0400
# 19727           326  2019-12-31 23:45:20.9780  2019-12-31 23:50:47.7490
#
#        start station id start station name  start station latitude  \
# ...

# %%
# result2021.columns

# %%
# result2021.columns = ['rideid', 'rideable type', 'starttime', 'stoptime',
#        'start station name', 'start station id', 'end station name',
#        'end station id', 'start station latitude', 'start station longitude', 'end station latitude', 'end station longitude',
#        'usertype']

# %%
# result2021.dropna()

# %%
# result2021.info()

# %%
# result2021['stoptime'] = pd.to_datetime(result2021['stoptime'])

# %%
# result2021['starttime'] = pd.to_datetime(result2021['starttime'])

# %%
# result2021['tripduration'] = result2021['stoptime'] - result2021['starttime']

# %%
# result2021['tripduration'] = result2021['tripduration']/np.timedelta64(1,'s')

# %%
# result2021['tripduration'] = result2021['tripduration'].astype(int)

# %%
# result2021.head()

# %%
# frames = [result2020, result2021]
frames1 = [result2019, result2020]
# frames2 = [result2019, result2020, result2021]

# %%
# results_20_21 = pd.concat(frames)
# results_19_20 = pd.concat(frames1)
results_all = pd.concat(frames1)

# %%
# results_20_21.to_csv('rides20_21.csv', index=False)

# %%
# results_19_20.to_csv('rides19_20.csv', index=False)

# %%
# result2020.to_csv('rides_2020.csv', index=False)

# %%
# result2019.to_csv('rides_2019.csv', index=False)

# %%
# result2021.to_csv('rides_2021.csv', index=False)

# %%
results_all.to_csv('rides.csv', index=False)
